# %% [markdown]
# ### This is a markdown cell. I hit escape and then M to create it. When I hit shift+enter it will be formatted according to the *markdown syntax* I've provided!

# %%
print("this is a code cell!")
print("when I hit shift+enter")
print("the code will be evaluated")
print("and the result will be output")
print("below the cell")
